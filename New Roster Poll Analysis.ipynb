# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import unidecode
import matplotlib.pylab as pl

from Roster_Poll import series_to_dict, sheet_to_dict, position_counts, position_counts_2cols 
from Roster_Poll import norm_pos, plot_time_series, plot_histograms
from Roster_Poll import gk_starter_counts, rb_starter_counts, lb_starter_counts
from Roster_Poll import cb_starter_counts, cdm_starter_counts, cm_starter_counts, cam_starter_counts
from Roster_Poll import wing_starter_counts, st_starter_counts, my_autopct, plot_starter_pies, last_3_filler

# %%
plt.style.use('seaborn')

# %% [markdown]
# # January 2023

# %%
jan_url = "https://docs.google.com/spreadsheets/d/1VGH14JVM574uutCtG-uXuqXLGS6vjGqS6F5ifEHNKGM/edit?usp=sharing"

# %%
jan_resps, jan_resp_nums = sheet_to_dict(jan_url)

# %%
jan_gk_series, norm_jan_gk_series, jan_gk_index, jan_gk_vals = position_counts(jan_resps[1], jan_resp_nums)

# %%
jan_rb_series, norm_jan_rb_series, jan_rb_index, jan_rb_vals = position_counts(jan_resps[3], jan_resp_nums)

# %%
jan_lb_series, norm_jan_lb_series, jan_lb_index, jan_lb_vals = position_counts(jan_resps[5], jan_resp_nums)

# %%
jan_cb_series, norm_jan_cb_series, jan_cb_index, jan_cb_vals = position_counts(jan_resps[7], jan_resp_nums)

# %%
jan_cdm_series, norm_jan_cdm_series, jan_cdm_index, jan_cdm_vals = position_counts(jan_resps[10], jan_resp_nums)

# %%
jan_cm_series, norm_jan_cm_series, jan_cm_index, jan_cm_vals = position_counts(jan_resps[12], jan_resp_nums)

# %%
jan_wing_series, norm_jan_wing_series, jan_wing_index, jan_wing_vals = position_counts(jan_resps[15], jan_resp_nums)

# %%
jan_st_series, norm_jan_st_series, jan_st_index, jan_st_vals = position_counts(jan_resps[18], jan_resp_nums)

# %%
# plot_histograms("January 2023", jan_gk_index, jan_gk_vals, jan_rb_index, jan_rb_vals, jan_lb_index, 
#                 jan_lb_vals, jan_cb_index, jan_cb_vals, jan_cdm_index, jan_cdm_vals, jan_cm_index, 
#                 jan_cm_vals, jan_wing_index, jan_wing_vals, jan_st_index, jan_st_vals)

# %% [markdown]
# # February 2023

# %%
feb_url = "https://docs.google.com/spreadsheets/d/1KpqAlkaEaWgDyHR1JMzywJ-e517Ulwl6ithwn6_mp6Q/edit?usp=sharing"

# %%
feb_resps, feb_resp_nums = sheet_to_dict(feb_url)

# %%
feb_gk_series, norm_feb_gk_series, feb_gk_index, feb_gk_vals = position_counts(feb_resps[3], feb_resp_nums)

# %%
feb_rb_series, norm_feb_rb_series, feb_rb_index, feb_rb_vals = position_counts(feb_resps[5], feb_resp_nums)

# %%
feb_lb_series, norm_feb_lb_series, feb_lb_index, feb_lb_vals = position_counts(feb_resps[7], feb_resp_nums)

# %%
feb_cb_series, norm_feb_cb_series, feb_cb_index, feb_cb_vals = position_counts(feb_resps[9], feb_resp_nums)

# %%
feb_cdm_series, norm_feb_cdm_series, feb_cdm_index, feb_cdm_vals = position_counts(feb_resps[12], feb_resp_nums)

# %%
feb_cm_series, norm_feb_cm_series, feb_cm_index, feb_cm_vals = position_counts(feb_resps[14], feb_resp_nums)

# %%
feb_wing_series, norm_feb_wing_series, feb_wing_index, feb_wing_vals = position_counts(feb_resps[17], feb_resp_nums)

# %%
feb_st_series, norm_feb_st_series, feb_st_index, feb_st_vals = position_counts(feb_resps[20], feb_resp_nums)

# %%
# plot_histograms("February 2023", feb_gk_index, feb_gk_vals, feb_rb_index, feb_rb_vals, feb_lb_index, 
#                 feb_lb_vals, feb_cb_index, feb_cb_vals, feb_cdm_index, feb_cdm_vals, feb_cm_index, 
#                 feb_cm_vals, feb_wing_index, feb_wing_vals, feb_st_index, feb_st_vals)

# %% [markdown]
# # March 2023

# %%
march_url = "https://docs.google.com/spreadsheets/d/1OUvi1Ivhe_WrRsp1dxzN7oZp73mMR2eWQUcZwtvHaD0/edit?usp=sharing"

# %%
march_resps, march_resp_nums = sheet_to_dict(march_url)

# %%
march_gk_series, norm_march_gk_series, march_gk_index, march_gk_vals = position_counts(march_resps[3], march_resp_nums)

# %%
march_rb_series, norm_march_rb_series, march_rb_index, march_rb_vals = position_counts(march_resps[5], march_resp_nums)

# %%
march_lb_series, norm_march_lb_series, march_lb_index, march_lb_vals = position_counts(march_resps[7], march_resp_nums)

# %%
march_cb_series, norm_march_cb_series, march_cb_index, march_cb_vals = position_counts(march_resps[9], march_resp_nums)

# %%
march_cdm_series, norm_march_cdm_series, march_cdm_index, march_cdm_vals = position_counts(march_resps[12], march_resp_nums)

# %%
march_cm_series, norm_march_cm_series, march_cm_index, march_cm_vals = position_counts(march_resps[14], march_resp_nums)

# %%
march_wing_series, norm_march_wing_series, march_wing_index, march_wing_vals = position_counts(march_resps[17], march_resp_nums)

# %%
march_st_series, norm_march_st_series, march_st_index, march_st_vals = position_counts(march_resps[20], march_resp_nums)

# %%
# plot_histograms("March 2023", march_gk_index, march_gk_vals, march_rb_index, march_rb_vals, march_lb_index, 
#                 march_lb_vals, march_cb_index, march_cb_vals, march_cdm_index, march_cdm_vals, march_cm_index, 
#                 march_cm_vals, march_wing_index, march_wing_vals, march_st_index, march_st_vals)

# %% [markdown]
# # April 2023

# %%
apr_url = "https://docs.google.com/spreadsheets/d/1g6HqB1n0PV5T_GtsAgN-eXOrqYEIfG9tElPVtOVDAeg/edit?usp=sharing"

# %%
apr_resps, apr_resp_nums = sheet_to_dict(apr_url)

# %%
apr_gk_series, norm_apr_gk_series, apr_gk_index, apr_gk_vals = position_counts_2cols(apr_resps[4], apr_resps[26], apr_resp_nums)

# %%
apr_rb_series, norm_apr_rb_series, apr_rb_index, apr_rb_vals = position_counts_2cols(apr_resps[6], apr_resps[28], apr_resp_nums)

# %%
apr_lb_series, norm_apr_lb_series, apr_lb_index, apr_lb_vals = position_counts_2cols(apr_resps[8], apr_resps[30], apr_resp_nums)

# %%
apr_cb_series, norm_apr_cb_series, apr_cb_index, apr_cb_vals = position_counts_2cols(apr_resps[10], apr_resps[32], apr_resp_nums)

# %%
apr_cam_series, norm_apr_cam_series, apr_cam_index, apr_cam_vals = position_counts(apr_resps[13], apr_resp_nums)

# %%
apr_cdm_series, norm_apr_cdm_series, apr_cdm_index, apr_cdm_vals = position_counts(apr_resps[35], apr_resp_nums)

# %%
apr_cm_series, norm_apr_cm_series, apr_cm_index, apr_cm_vals = position_counts_2cols(apr_resps[15], apr_resps[37], apr_resp_nums)

# %%
apr_wing_series, norm_apr_wing_series, apr_wing_index, apr_wing_vals = position_counts_2cols(apr_resps[18], apr_resps[40], apr_resp_nums)

# %%
apr_st_series, norm_apr_st_series, apr_st_index, apr_st_vals = position_counts_2cols(apr_resps[21], apr_resps[43], apr_resp_nums)

# %%
# plot_histograms("April 2023", apr_gk_index, apr_gk_vals, apr_rb_index, apr_rb_vals, apr_lb_index, 
#                 apr_lb_vals, apr_cb_index, apr_cb_vals, apr_cdm_index, apr_cdm_vals, apr_cm_index, 
#                 apr_cm_vals, apr_cam_index, apr_cam_vals, apr_wing_index, apr_wing_vals, 
#                 apr_st_index, apr_st_vals)

# %% [markdown]
# # May 2023

# %%
may_url = "https://docs.google.com/spreadsheets/d/1YXrhUS5gLaPnyXpeNnBpW0BFd9VllhnI5UC6JTjCUTw/edit?usp=sharing"

# %%
may_resps, may_resp_nums = sheet_to_dict(may_url)

# %%
may_gk_series, norm_may_gk_series, may_gk_index, may_gk_vals = position_counts_2cols(may_resps[22], may_resps[44], may_resp_nums)

# %%
may_rb_series, norm_may_rb_series, may_rb_index, may_rb_vals = position_counts_2cols(may_resps[24], may_resps[46], may_resp_nums)

# %%
may_lb_series, norm_may_lb_series, may_lb_index, may_lb_vals = position_counts_2cols(may_resps[26], may_resps[48], may_resp_nums)

# %%
may_cb_series, norm_may_cb_series, may_cb_index, may_cb_vals = position_counts_2cols(may_resps[28], may_resps[50], may_resp_nums)

# %%
may_cam_series, norm_may_cam_series, may_cam_index, may_cam_vals = position_counts(may_resps[31], may_resp_nums)

# %%
may_cdm_series, norm_may_cdm_series, may_cdm_index, may_cdm_vals = position_counts(may_resps[53], may_resp_nums)

# %%
may_cm_series, norm_may_cm_series, may_cm_index, may_cm_vals = position_counts_2cols(may_resps[33], may_resps[55], may_resp_nums)

# %%
may_wing_series, norm_may_wing_series, may_wing_index, may_wing_vals = position_counts_2cols(may_resps[36], may_resps[58], may_resp_nums)

# %%
may_st_series, norm_may_st_series, may_st_index, may_st_vals = position_counts_2cols(may_resps[39], may_resps[61], may_resp_nums)

# %%
# plot_histograms("May 2023", may_gk_index, may_gk_vals, may_rb_index, may_rb_vals, may_lb_index, 
#                 may_lb_vals, may_cb_index, may_cb_vals, may_cdm_index, may_cdm_vals, may_cm_index, 
#                 may_cm_vals, may_cam_index, may_cam_vals, may_wing_index, may_wing_vals, 
#                 may_st_index, may_st_vals)

# %% [markdown]
# # June 2023

# %%
june_url = "https://docs.google.com/spreadsheets/d/1HSErADnb6hE64SJGYx-gCQmf68o4SOxknvzsc7Zcy_I/edit?usp=sharing"

# %%
june_resps, june_resp_nums = sheet_to_dict(june_url)

# %%
june_gk_series, norm_june_gk_series, june_gk_index, june_gk_vals = position_counts_2cols(june_resps[3], june_resps[25], june_resp_nums)

# %%
june_rb_series, norm_june_rb_series, june_rb_index, june_rb_vals = position_counts_2cols(june_resps[5], june_resps[27], june_resp_nums)

# %%
june_lb_series, norm_june_lb_series, june_lb_index, june_lb_vals = position_counts_2cols(june_resps[7], june_resps[29], june_resp_nums)

# %%
june_cb_series, norm_june_cb_series, june_cb_index, june_cb_vals = position_counts_2cols(june_resps[9], june_resps[31], june_resp_nums)

# %%
june_cam_series, norm_june_cam_series, june_cam_index, june_cam_vals = position_counts(june_resps[12], june_resp_nums)

# %%
june_cdm_series, norm_june_cdm_series, june_cdm_index, june_cdm_vals = position_counts(june_resps[34], june_resp_nums)

# %%
june_cm_series, norm_june_cm_series, june_cm_index, june_cm_vals = position_counts_2cols(june_resps[14], june_resps[36], june_resp_nums)

# %%
june_wing_series, norm_june_wing_series, june_wing_index, june_wing_vals = position_counts_2cols(june_resps[17], june_resps[39], june_resp_nums)

# %%
june_st_series, norm_june_st_series, june_st_index, june_st_vals = position_counts_2cols(june_resps[20], june_resps[42], june_resp_nums)

# %%
# plot_histograms("June 2023", june_gk_index, june_gk_vals, june_rb_index, june_rb_vals, june_lb_index, 
#                 june_lb_vals, june_cb_index, june_cb_vals, june_cdm_index, june_cdm_vals, june_cm_index, 
#                 june_cm_vals, june_cam_index, june_cam_vals, june_wing_index, june_wing_vals, 
#                 june_st_index, june_st_vals)

# %% [markdown]
# # June 2023

# %%
july_url = "https://docs.google.com/spreadsheets/d/10Da0yn4hzI_VRCPrFsSrCsQajRDOl9Ff-SEuHw3skA4/edit?usp=sharing"

# %%
july_resps, july_resp_nums = sheet_to_dict(july_url)

# %%
july_gk_series, norm_july_gk_series, july_gk_index, july_gk_vals = position_counts_2cols(july_resps[3], july_resps[25], july_resp_nums)

# %%
july_rb_series, norm_july_rb_series, july_rb_index, july_rb_vals = position_counts_2cols(july_resps[5], july_resps[27], july_resp_nums)

# %%
july_lb_series, norm_july_lb_series, july_lb_index, july_lb_vals = position_counts_2cols(july_resps[7], july_resps[29], july_resp_nums)

# %%
july_cb_series, norm_july_cb_series, july_cb_index, july_cb_vals = position_counts_2cols(july_resps[9], july_resps[31], july_resp_nums)

# %%
july_cam_series, norm_july_cam_series, july_cam_index, july_cam_vals = position_counts(july_resps[12], july_resp_nums)

# %%
july_cdm_series, norm_july_cdm_series, july_cdm_index, july_cdm_vals = position_counts(july_resps[34], july_resp_nums)

# %%
july_cm_series, norm_july_cm_series, july_cm_index, july_cm_vals = position_counts_2cols(july_resps[14], july_resps[36], july_resp_nums)

# %%
july_wing_series, norm_july_wing_series, july_wing_index, july_wing_vals = position_counts_2cols(july_resps[17], july_resps[39], july_resp_nums)

# %%
july_st_series, norm_july_st_series, july_st_index, july_st_vals = position_counts_2cols(july_resps[20], july_resps[42], july_resp_nums)

# %%
plot_histograms("July 2023", july_gk_index, july_gk_vals, july_rb_index, july_rb_vals, july_lb_index, 
                july_lb_vals, july_cb_index, july_cb_vals, july_cdm_index, july_cdm_vals, july_cm_index, 
                july_cm_vals, july_cam_index, july_cam_vals, july_wing_index, july_wing_vals, 
                july_st_index, july_st_vals)

# %% [markdown]
# # Month by Month

# %%
goalkeepers = {'January 2023': norm_jan_gk_series,
               'February 2023': norm_feb_gk_series,
               'March 2023': norm_march_gk_series,
               'April 2023': norm_apr_gk_series,
               'May 2023': norm_may_gk_series,
               'June 2023': norm_june_gk_series,
               'July 2023': norm_july_gk_series}

right_backs = {'January 2023': norm_jan_rb_series,
               'February 2023': norm_feb_rb_series,
               'March 2023': norm_march_rb_series,
               'April 2023': norm_apr_rb_series,
               'May 2023': norm_may_rb_series,
               'June 2023': norm_june_rb_series,
               'July 2023': norm_july_rb_series}

left_backs = {'January 2023': norm_jan_lb_series,
              'February 2023': norm_feb_lb_series,
              'March 2023': norm_march_lb_series,
              'April 2023': norm_apr_lb_series,
              'May 2023': norm_may_lb_series,
              'June 2023': norm_june_lb_series,
              'July 2023': norm_july_lb_series}

centerbacks = {'January 2023': norm_jan_cb_series,
               'February 2023': norm_feb_cb_series,
               'March 2023': norm_march_cb_series,
               'April 2023': norm_apr_cb_series,
               'May 2023': norm_may_cb_series,
               'June 2023': norm_june_cb_series,
               'July 2023': norm_july_cb_series}

def_mids = {'January 2023': norm_jan_cdm_series,
            'February 2023': norm_feb_cdm_series,
            'March 2023': norm_march_cdm_series,
            'April 2023': norm_apr_cdm_series,
            'May 2023': norm_may_cdm_series,
            'June 2023': norm_june_cdm_series,
            'July 2023': norm_july_cdm_series}

cent_mids = {'January 2023': norm_jan_cm_series,
             'February 2023': norm_feb_cm_series,
             'March 2023': norm_march_cm_series,
             'April 2023': norm_apr_cm_series,
             'May 2023': norm_may_cm_series,
             'June 2023': norm_june_cm_series,
             'July 2023': norm_july_cm_series}

atk_mids = {'January 2023': pd.Series([]),
            'February 2023': pd.Series([]),
            'March 2023': pd.Series([]),
            'April 2023': norm_apr_cam_series,
            'May 2023': norm_may_cam_series,
            'June 2023': norm_june_cam_series,
            'July 2023': norm_july_cam_series}

wingers = {'January 2023': norm_jan_wing_series,
           'February 2023': norm_feb_wing_series,
           'March 2023': norm_march_wing_series,
           'April 2023': norm_apr_wing_series,
           'May 2023': norm_may_wing_series,
           'June 2023': norm_june_wing_series,
           'July 2023': norm_july_wing_series}

strikers = {'January 2023': norm_jan_st_series,
            'February 2023': norm_feb_st_series,
            'March 2023': norm_march_st_series,
            'April 2023': norm_apr_st_series,
            'May 2023': norm_may_st_series,
            'June 2023': norm_june_st_series,
            'July 2023': norm_july_st_series}
# Out:
# /var/folders/7q/fly3z8xs21vc5yvc2rqhgmkh0000gn/T/ipykernel_80994/3968258734.py:49: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   atk_mids = {'January 2023': pd.Series([]),
# /var/folders/7q/fly3z8xs21vc5yvc2rqhgmkh0000gn/T/ipykernel_80994/3968258734.py:50: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   'February 2023': pd.Series([]),
# /var/folders/7q/fly3z8xs21vc5yvc2rqhgmkh0000gn/T/ipykernel_80994/3968258734.py:51: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   'March 2023': pd.Series([]),

# %%
norm_keepers = norm_pos(goalkeepers)
len_nk = len(norm_keepers)

norm_right_backs = norm_pos(right_backs)
len_nrb = len(norm_right_backs)

norm_left_backs = norm_pos(left_backs)
len_nlb = len(norm_left_backs)

norm_centerbacks = norm_pos(centerbacks)
len_ncb = len(norm_centerbacks)

norm_def_mids = norm_pos(def_mids)
len_ndm = len(norm_def_mids)

norm_cent_mids = norm_pos(cent_mids)
len_ncm = len(norm_cent_mids)

norm_atk_mids = norm_pos(atk_mids)
len_nam = len(norm_atk_mids)

norm_wingers = norm_pos(wingers)
len_nw = len(norm_wingers)

norm_strikers = norm_pos(strikers)
len_ns = len(norm_strikers)

# %%
plot_time_series(norm_keepers, len_nk, norm_right_backs, len_nrb, norm_left_backs,
                    len_nlb, norm_centerbacks, len_ncb, norm_def_mids, len_ndm,
                    norm_cent_mids, len_ncm, norm_atk_mids, len_nam, norm_wingers, 
                    len_nw, norm_strikers, len_ns)

# %%
fig, axes = plt.subplots(figsize = (28,20), sharex = True)

norm_keepers.T.plot.line(ax=axes, color = pl.cm.gist_rainbow(0), 
                         style = 'o-', lw=6)
axes.legend(ncol=2, fontsize=16, bbox_to_anchor=(1.0, 1.0))
#axes.set_title('Goalkeepers', fontweight='heavy', fontsize=30)
#axes.set_facecolor('darkgray')

norm_right_backs.T.plot.line(ax=axes, color = pl.cm.gist_rainbow(31), 
                         style = 'o-', lw=6)
axes.legend(ncol=2, fontsize=16, bbox_to_anchor=(1.0, 1.0))
#axes.set_title('Right Backs', fontweight='heavy', fontsize=30)
#axes.set_facecolor('darkgray')

norm_left_backs.T.plot.line(ax=axes, color = pl.cm.gist_rainbow(63), 
                         style = 'o-', lw=6)
axes.legend(ncol=2, fontsize=16, bbox_to_anchor=(1.0, 1.0))
#axes.set_title('Left Backs', fontweight='heavy', fontsize=30)
#axes.set_facecolor('darkgray')

norm_centerbacks.T.plot.line(ax=axes, color = pl.cm.gist_rainbow(95), 
                         style = 'o-', lw=6)
axes.legend(ncol=2, fontsize=16, bbox_to_anchor=(1.0, 1.0))
#axes.set_title('Centerbacks', fontweight='heavy', fontsize=30)
#axes.set_facecolor('darkgray')

norm_def_mids.T.plot.line(ax=axes, color = pl.cm.gist_rainbow(127), 
                         style = 'o-', lw=6)
axes.legend(ncol=2, fontsize=16, bbox_to_anchor=(1.0, 1.0))
#axes.set_title('Defensive Midfielders', fontweight='heavy', fontsize=30)
#axes.set_facecolor('darkgray')

norm_cent_mids.T.plot.line(ax=axes, color = pl.cm.gist_rainbow(159), 
                         style = 'o-', lw=6)
axes.legend(ncol=2, fontsize=16, bbox_to_anchor=(1.0, 1.0))
#axes.set_title('Central Midfielders', fontweight='heavy', fontsize=30)
#axes.set_facecolor('darkgray')

norm_atk_mids.T.plot.line(ax=axes, color = pl.cm.gist_rainbow(191), 
                         style = 'o-', lw=6)
axes.legend(ncol=2, fontsize=16, bbox_to_anchor=(1.0, 1.0))
#axes.set_title('Attacking Midfielders', fontweight='heavy', fontsize=30)
#axes.set_facecolor('darkgray')

norm_wingers.T.plot.line(ax=axes, color = pl.cm.gist_rainbow(223), 
                         style = 'o-', lw=6)
axes.legend(ncol=2, fontsize=16, bbox_to_anchor=(1.0, 1.0))
#axes.set_title('Wingers', fontweight='heavy', fontsize=30)
#axes[3][0].set_xticks(fontsize=14)
#axes.set_facecolor('darkgray')

norm_strikers.T.plot.line(ax=axes, color = pl.cm.gist_rainbow(255), 
                         style = 'o-', lw=6)
axes.legend(ncol=4, fontsize=16, bbox_to_anchor=(1.0, 1.0))
#axes.set_title('Strikers', fontweight='heavy', fontsize=30)
#axes[3][1].set_xticks(fontsize=14)
axes.set_facecolor('darkgray')

#fig.tight_layout(w_pad=1.8)
axes.set_title('Roster Selection Percentages Over Time', fontsize=40, fontweight='heavy')
axes.tick_params(axis='both', which='major', labelsize=20)
plt.subplots_adjust(top=0.9)
#plt.savefig('roster_trends.png')
plt.show()

# %% [markdown]
# # Stock Up/ Stock Down

# %%
#pull last two columns of time series data
cols = list(norm_strikers.columns[-2:])+['POS']

#add positions for each player
norm_strikers['POS'] = 'ST'
norm_wingers['POS'] = 'Wing'
norm_cent_mids['POS'] = 'CM'
norm_def_mids['POS'] = 'CDM'
norm_centerbacks['POS'] = 'CB'
norm_left_backs['POS'] = 'LB'
norm_right_backs['POS'] = 'RB'
norm_keepers['POS'] = 'GK'

#join all data together
susd = pd.concat([norm_strikers[cols], norm_wingers[cols], norm_cent_mids[cols], 
                  norm_def_mids[cols], norm_centerbacks[cols], 
                  norm_left_backs[cols], norm_right_backs[cols], norm_keepers[cols]])

# %%
susd
# Out:
#                  June 2023  July 2023 POS
# Ricardo Pepi      0.905263   0.914894  ST
# Josh Sargent      0.042105   0.042553  ST
# Folarin Balogun   0.978947   0.978723  ST
# Daryl Dike        0.010526   0.000000  ST
# Haji Wright       0.000000   0.000000  ST
# ...                    ...        ...  ..
# ?                 0.000000   0.000000  GK
# Mcmath            0.000000   0.000000  GK
# Diego Kochen      0.000000   0.000000  GK
# Josh Cohen        0.010526   0.021277  GK
# Drake Callender   0.000000   0.042553  GK
#
# [175 rows x 3 columns]

# %%
up_downs = []


for val in range(len(susd)):
    up_downs.append(susd.iloc[val, 1] - susd.iloc[val, 0])
    
susd['SUSD'] = up_downs

susd = susd.sort_values('SUSD', ascending=False)

# %%
susd.iloc[0:9, -2:]
# Out:
#                    POS      SUSD
# Taylor Booth      Wing  0.278835
# Auston Trusty       CB  0.227324
# Brendan Aaronson  Wing  0.218365
# DeJuan Jones        LB  0.202240
# James Sands        CDM  0.159544
# Tanner Tessman     CDM  0.153846
# Jalen Neal          CB  0.128331
# Caleb Wiley         LB  0.097872
# Tim Ream            CB  0.097424

# %%
susd.iloc[-9:, -2:]
# Out:
#                      POS      SUSD
# Joe Scally            RB -0.076148
# Ethan Horvath         GK -0.078611
# Aidan Morris         CDM -0.111111
# Josh Sargent        Wing -0.115342
# Walker Zimmerman      CB -0.146697
# John Tolkin           LB -0.200000
# Alejandro Zendejas  Wing -0.262710
# Johnny Cardoso       CDM -0.287749
# Miles Robinson        CB -0.501008

# %% [markdown]
# # Starters

# %%
player_mistakes = {
    'Matt Turner' : ['Matt', 'Turner', 'Turnee', 'turner', 'Turner.', 'Matty', 'Ice', 'MattTurner'],
    'Ethan Horvath' : ['Ethan', 'Horvath', 'horvath'],
    'Zack Steffen' : ['Zack', 'Steffen', 'Steffan'],
    'Gabriel Slonina' : ['Gabriel', 'Slonina', 'Gaga', 'gaga', 'slonina'],
    'Sergino Dest' : ['Sergino', 'Sergio', 'Dest', 'dest', 'Deat', 'Serge'],
    'Joe Scally' : ['Joe', 'Scally', 'scally', 'Joes', 'The', 'Scallywag'],
    'Reggie Cannon' : ['Reggie', 'Cannon'],
    'Antonee Robinson' : ['Antonee', 'Jedi', 'Robinson', 'jedi', 'robinson', 'Robinsion',
                         'A', 'Rob', 'rob', 'Arob', 'ARob', 'A.', 'Anyone', 'Antony', 'A-Rob', 
                         'Anthony'],
    'Kevin Paredes' : ['Kevin', 'Paredes', 'Parades', 'paredes', 'Kp', 'Keevin', 'Parrdes'],
    'John Tolkin' : ['John', 'Tolkin'],
    'Caleb Wiley' : ['Caleb', 'Wiley', 'Wylie', 'wiley', 'Willey'],
    'Chris Richards' : ['Chris', 'Richards', 'chris', 'richards', 'Richardson', "Richard's", 
                       'Richard’s', 'Ricards', 'RIchards', 'R', 'Cr', 'Richads'],
    'Walker Zimmerman' : ['Walker', 'Zimmerman', 'Zimm', 'Wlaker', 'Zimmermann', 'Zim', 'zim'],
    'John Brooks' : ['John', 'Brooks', 'J', 'brooks'],
    'Cameron Carter-Vickers' : ['Cameron', 'Carter-Vickers', 'Carter', 'CCV', 'Carters', 'Ccv', 'ccv',
                                'Vickers', 'vickers', 'vicks', 'Carter-vickers', 'carter', 'Cahtah-Vickas',
                                'CCCV'],
    'Tim Ream' : ['Tim', 'Ream', 'TIM', 'MF', 'REAM', 'ream', 'Tr', 'Team'],
    'Mark McKenzie' : ['Mark', 'McKenzie', 'Mckenzie', 'mckenzie', 'McKenzey', 'McKenzke', 'Makenzie'],
    'Erik Palmer-Brown' : ['Erik', 'Palmer-Brown', 'EPB', 'Palmer', 'Brown', 'palmer', 'brown', 
                           'Eric', 'Erick'],
    'Miles Robinson' : ['Miles', 'Robinson', 'robinson', 'Mrob', 'Rob', 'M'],
    'Justin Che' : ['Justin', 'Che'],
    'Tyler Adams' : ['Tyler', 'Adams', 'adams', "Adam's", 'Adans', 'tyler', 'Tylar'],
    'Matt Miazga' : ['Matt', 'Maizga', 'Miazga'],
    'Auston Trusty' : ['Auston', 'Trusty', 'Austin', 'trusty', 'Aaron'],
    'James Sands' : ['James', 'Sands', 'sands', 'Jordan', 'james'],
    'Weston McKennie' : ['Weston', 'Wes', 'McKennie', 'McKinnie', 'Mckennie', 'weston', 'McKenny', 'wes',
                        'weston', 'Westin', 'mckennie', 'Mckinnie', 'McKennir', 'MCKENNIE', 'mckinnie',
                        'McKennnie', 'Wizarding', 'World', 'of'],
    'Obed Vargas' : ['Obed', 'Vargas', 'vargas', 'Vargus'],
    'Yunus Musah' : ['Yunus', 'Musah', 'Musa', 'Yunis', 'Yunas', 'musah', 'Yunad', "Yuma’s",
                     'Yunes', 'Yunaa', 'Mlmusah', 'Yunush'],
    'Gio Reyna' : ['Gio', 'Reyna', 'Giovanni', 'Giovani', 'reyna', 'gio', 'Reyan', 'REYNA', 'Gii'],
    'Brendan Aaronson' : ['Brendan', 'Aaronson', 'Brenden', 'B', 'b', 'aaronson', 'Aaronsen', 'aronson', 'B.',
                          'Brendon', 'AARONSON', 'arronson', 'A-a-ronson', 'Brandon'],
    'Alejandro Zendejas' : ['Alejandro', 'Zendejas', 'zendejas', 'Zendajas', 'Alex'],
    'Luca de la Torre' : ['Luca', 'de', 'la', 'Torre', 'De', 'La', 'LDLT', 'Ldlt', 'torre', 'Delatorre',
                         'Tore', 'le', 'DLT', 'LaTorre', 'TOrre'],
    'Paxten Aaronson' : ['Paxten', 'Aaronson', 'P', 'Paxton', 'Aaronsen', 'aaronson', 'Parten', 'P.',
                         'Aronson', 'Aaaronson'],
    'Christian Pulisic' : ['Christian', 'Pulisic', 'Puli', 'Cristian', 'puli', 'Pullisic', 'CP',
                          'Pulisc', 'pulisic', 'Chrisian', 'Puligoat', 'Pulici', 'Chrisitan', 'cp', 'CP10',
                          'puliGOAT', 'Pulisi', 'Pusilic', 'Pulsiic', 'Pulicic', 'Pulišić'],
    'Tim Weah' : ['Tim', 'Weah', 'Timothy', 'Timo', 'Timmothy', 'weah', 'Tw', 'tw', 'Timithoy', 'Timmy'],
    'Jesus Ferreira' : ['Jesus', 'Ferreira', 'Ferreria', 'J', 'ferreira', 'jesus', 'ferreria', 'Jesús', 
                        'Ferraira', 'Ferriera'],
    'Ricardo Pepi' : ['Ricardo', 'Pepi', 'pepi', 'Pepei'],
    'Jordan Pefok' : ['Jordan', 'Pefok'],
    'Daryl Dike' : ['Daryl', 'Dike', 'Darryl', 'DIKE'],
    'Josh Sargent' : ['Josh', 'Sargent', 'Sarge', 'Sagrent', 'Sergant', 'Sargeant', 'sargent'],
    'Brandon Vazquez' : ['Brandon', 'Vazquez', 'Vasquez', 'vazquez'],
    'Folarin Balogun' : ['Folarin', 'Balogun', 'balogun', 'BALOGUN', 'BALO', 'Bologan', 'Balagon', 
                         'Florian', 'Balogan', 'Floating', 'Balo', 'Flo', 'Floarin', 'Falorin', 'Fb',
                         'Bologun', 'Baloguin', 'Folirian', 'Folarian', 'Balagoun', 'Belagun', 'Balogub',
                         'Falogun'],
    'Haji Wright' : ['Haji', 'Wright', 'wright'],
    'Malik Tillman' : ['Malik', 'Tillman', 'Tilman', 'M', 'tillman', 'M.', 'Mallick'],
    'DeAndre Yedlin' : ['DeAndre', 'Yedlin', 'Deandre'],
    'Djordje Mihailovic' : ['Djordje', 'Mihailovic', 'Djordie', 'Mihilovik', 'Mihalovic', 'Djorjde',
                           'Mihailovik', 'mihailovic', 'Djorde', 'Mihailovich', 'Mihilovic'],
    'Christian Roldan' : ['Christian', 'Roldan', 'Cristian', 'ROLDAN'],
    'Gianluca Busio' : ['Gianluca', 'Busio'],
    'Aaron Long' : ['Aaron', 'Long', 'long'],
    'Kellyn Acosta' : ['Kellyn', 'Acosta', 'Kelly’s'],
    'Paul Arriola' : ['Paul', 'Arriola', 'Arriolla'],
    'Sam Vines' : ['Sam', 'Vines'],
    'Diego Luna' : ['Diego', 'Luna'],
    'Alex Mendez' : ['Alex', 'Mendez'],
    'Thomas Gaudin' : ['Thomas', 'Gaudin'],
    'Alejandro Alvarado Jr.' : ['Alejandro', 'Alvarado', 'jr', 'Jr.', 'Ale'],
    'Niko Tsakiris' : ['Niko', 'Tsakiris'],
    'Richie Ledezma' : ['Richie', 'Ledezma', 'Ledesma'],
    'Matthew Hoppe' : ['Matthew', 'Hoppe', 'F.'],
    'Cade Cowell' : ['Cade', 'Cowell', 'cowell', 'Case', 'Cowel'],
    'Taylor Booth' : ['Taylor', 'Booth', 'booth'],
    'Quinn Sullivan' : ['Quinn', 'Sullivan'],
    'Alan Sonora' : ['Alan', 'Sonora', 'sonara'],
    'Jonathan Gomez' : ['Jonathan', 'Gomez', 'Johnathan', 'gomes'],
    'Mauricio Cuevas' : ['Mauricio', 'Cuevas'],
    'Brandon Craig' : ['Brandon', 'Craig', 'Brandan'],
    'Keaton Parks' : ['Keaton', 'Parks'],
    'Unknown': ['Unknown', '?', 'Tbd'],
    'Bryan Reynolds': ['Bryan', 'Reynolds', 'Brian', 'Bryen'],
    'Jalen Neal': ['Jalen', 'Neal'],
    'Roman Celentano': ['Roman', 'Celentano'],
    'Johnny Cardoso': ['Johnny', 'Cardoso', 'Cardosa', 'Cordoso'],
    'Gyasi Zardes': ['Gyasi', 'Zardes'],
    'Joshua Wynder': ['Joshua', 'Josh', 'Wynder', 'Wylnder'],
    'Cruz Medina': ['Cruz', 'Medina'],
    'Jack McGlynn': ['Jack', 'McGlynn', 'Mcglynn', 'Mcgynn', 'mcglynn'],
    'Caden Clark': ['Caden', 'Clark', 'clark'],
    'Daniel Edelman': ['Daniel', 'Edleman', 'Edelman'],
    'Julian Gressel': ['Julian', 'Gressel'],
    'George Bello': ['George', 'Bello'],
    'Cavan Sullivan': ['Cavan', 'Caven', 'Sullivan'],
    'Maximo Carrizo': ['Maximo', 'Carrizo'],
    'Keyrol Figueroa': ['Keyrol', 'Figueroa', 'Keylor', 'Figuroa'],
    'Malick Sanogo': ['Malick', 'Sanogo'],
    'DeJuan Jones': ['DeJuan', 'Dejuan', 'Jones'],
    'Jaheim Headley': ['Jaheim', 'Headley'],
    'Rokas Pukstas': ['Rokas', 'Pukstas', 'pukstas'],
    'Tanner Tessman': ['Tanner', 'Tessman', 'Tessmann'],
    'Eryk Williamson': ['Eryk', 'Eric', 'Williamson', 'williamson'],
    'Cole Bassett': ['Cole', 'Bassett'],
    'Jordan Morris': ['Jordan', 'Morris', 'jordan', 'morris'],
    'Paxton Pomykal': ['Paxton', 'Pomykal'],
    'Brian Gutierrez': ['Brian', 'Gutierrez', 'Guitierez'],
    'Tim Tillman': ['Tim', 'Tillman', 'tillman', 'Timothy'],
    'Aidan Morris': ['Aidan', 'Morris', 'Aiden'],
    'Andrew Carleton': ['Andrew', 'Carleton'],
    'Clint Dempsey': ['Clint', 'Dempsey'],
    'Landon Donovan': ['Landon', 'Donovan'],
    'Luca Koleosho': ['Luca', 'Koleosho'],
    'Shaq Moore': ['Shaq', 'Moore'],
    'Nicholas Gioacchini': ['Nicholas', 'Gioacchini'],
    'Reed Baker-Whiting': ['Reed', 'Baker', 'Whiting', 'Baker-Whiting'],
    'Mauricio Isais': ['Mauricio', 'Isais'],
    'Henry Kessler': ['Henry', 'Kessler'],
    'Pedro Soma': ['Pedro', 'Soma'],
    'Darren Yapi': ['Darren', 'Yapi'],
    'Noel Buck': ['Noel', 'Buck'],
    'Konrad de la Fuente': ['Konrad', 'de', 'De', 'la', 'La', 'Fuente']
 }

# %%
gk_counts = {'Matt Turner' : 0,
             'Zack Steffen': 0,
             'Ethan Horvath': 0,
             'Gabriel Slonina': 0,
             'Roman Celentano': 0,
             'Unknown': 0}

gk_starts1 = july_resps[4].value_counts()
gk_starts2 = july_resps[26].value_counts()
gk_starts = gk_starts1.add(gk_starts2, fill_value=0)

gk_count = gk_starter_counts(gk_starts, gk_counts, player_mistakes)

# %%
gk_count
# Out:
# Matt Turner        45.0
# Gabriel Slonina     1.0
# dtype: float64

# %%
sum(gk_count.values)
# Out:
# 46.0

# %%
rb_counts = {'Sergino Dest' : 0,
             'Reggie Cannon': 0,
             'Joe Scally': 0,
             'Bryan Reynolds': 0,
             'Tim Weah': 0,
             'Unknown': 0}

rb_starts1 = july_resps[6].value_counts()
rb_starts2 = july_resps[28].value_counts()
rb_starts = rb_starts1.add(rb_starts2, fill_value=0)

rb_count = rb_starter_counts(rb_starts, rb_counts, player_mistakes)

# %%
rb_count
# Out:
# Sergino Dest    37.0
# Joe Scally       9.0
# dtype: float64

# %%
sum(rb_count.values)
# Out:
# 46.0

# %%
lb_counts = {'Antonee Robinson' : 0,
             'Kevin Paredes' : 0,
             'John Tolkin' : 0,
             'Caleb Wiley' : 0,
             'Sergino Dest': 0,
             'Joe Scally': 0,
             'Tim Weah': 0,
             'Jonathan Gomez': 0,
             'George Bello': 0,
             'Unknown': 0}

lb_starts1 = july_resps[8].value_counts()
lb_starts2 = july_resps[30].value_counts()
lb_starts = lb_starts1.add(lb_starts2, fill_value=0)

lb_count = lb_starter_counts(lb_starts, lb_counts, player_mistakes)

# %%
lb_count
# Out:
# Antonee Robinson    44.0
# Joe Scally           1.0
# Tim Weah             1.0
# dtype: float64

# %%
sum(lb_count.values)
# Out:
# 46.0

# %%
lcb_counts = {'Chris Richards' : 0,
             'Walker Zimmerman': 0,
             'John Brooks': 0,
             'Cameron Carter-Vickers': 0,
             'Tyler Adams': 0,
             'Tim Ream': 0,
             'Miles Robinson': 0,
             'Mark McKenzie': 0,
             'Matt Miazga': 0,
             'Justin Che': 0,
             'Auston Trusty' : 0,
             'James Sands' : 0,
             'Erik Palmer-Brown' : 0,
             'Jalen Neal': 0,
             'Reggie Cannon': 0,
             'Joshua Wynder': 0,
             'Aaron Long': 0,
             'Antonee Robinson': 0,
             'Unknown': 0}

rcb_counts = {'Chris Richards' : 0,
             'Walker Zimmerman': 0,
             'John Brooks': 0,
             'Cameron Carter-Vickers': 0,
             'Tyler Adams': 0,
             'Tim Ream': 0,
             'Miles Robinson': 0,
             'Mark McKenzie': 0,
             'Matt Miazga': 0,
             'Justin Che': 0,
             'Auston Trusty' : 0,
             'James Sands' : 0,
             'Erik Palmer-Brown' : 0,
             'Jalen Neal': 0,
             'Reggie Cannon': 0,
             'Joshua Wynder': 0,
             'Aaron Long': 0,
             'Antonee Robinson': 0,
             'Unknown': 0}

lcb_starts1 = july_resps[10].value_counts()
lcb_starts2 = july_resps[32].value_counts()
lcb_starts = lcb_starts1.add(lcb_starts2, fill_value=0)

rcb_starts1 = july_resps[11].value_counts()
rcb_starts2 = july_resps[33].value_counts()
rcb_starts = rcb_starts1.add(rcb_starts2, fill_value=0)

lcb_count = cb_starter_counts(lcb_starts, lcb_counts, player_mistakes)

rcb_count = cb_starter_counts(rcb_starts, rcb_counts, player_mistakes)

# %%
lcb_count
# Out:
# Chris Richards            25.0
# Walker Zimmerman           1.0
# Cameron Carter-Vickers     5.0
# Tim Ream                   9.0
# Miles Robinson             2.0
# Auston Trusty              2.0
# Jalen Neal                 2.0
# dtype: float64

# %%
sum(lcb_count.values)
# Out:
# 46.0

# %%
rcb_count
# Out:
# Chris Richards            19.0
# Cameron Carter-Vickers    18.0
# Miles Robinson             6.0
# Auston Trusty              2.0
# Joshua Wynder              1.0
# dtype: float64

# %%
sum(rcb_count.values)
# Out:
# 46.0

# %%
cdm_counts = {'Tyler Adams' : 0,
              'Weston McKennie': 0,
              'Obed Vargas': 0,
              'Kellyn Acosta': 0,
              'Johnny Cardoso': 0,
              'Tanner Tessman': 0,
              'Yunus Musah': 0}

cdm_starts = july_resps[35].value_counts()

cdm_count = cdm_starter_counts(cdm_starts, cdm_counts, player_mistakes)

# %%
cdm_starts
# Out:
# Adams          6
# Tyler Adams    3
# Tyler adams    1
# Tyler          1
# Yunus Musah    1
# adams          1
# Name: 35, dtype: int64

# %%
cdm_count
# Out:
# Tyler Adams    12
# Yunus Musah     1
# dtype: int64

# %%
len(july_resps[35].dropna()) == sum(cdm_count)
# Out:
# True

# %%
cam_counts = {'Gio Reyna' : 0,
              'Brendan Aaronson': 0,
              'Malik Tillman': 0,
              'Tyler Adams': 0,
              'Unknown': 0}

cam_starts = july_resps[13].value_counts()

cam_count = cam_starter_counts(cam_starts, cam_counts, player_mistakes)

# %%
cam_count
# Out:
# Gio Reyna    33
# dtype: int64

# %%
len(july_resps[13].dropna()) == sum(cam_count)
# Out:
# True

# %%
lcm_counts = {'Weston McKennie' : 0,
              'Yunus Musah': 0,
              'Gio Reyna': 0,
              'Brendan Aaronson': 0,
              'Alejandro Zendejas' : 0,
              'Luca de la Torre' : 0,
              'Paxten Aaronson' : 0,
              'Alex Mendez': 0,
              'Taylor Booth': 0,
              'Keaton Parks': 0,
              'Richie Ledezma': 0,
              'Malik Tillman': 0,
              'Tyler Adams': 0,
              'Djordje Mihailovic': 0,
              'Tim Tillman': 0,
              'Unknown': 0}

rcm_counts = {'Weston McKennie' : 0,
              'Yunus Musah': 0,
              'Gio Reyna': 0,
              'Brendan Aaronson': 0,
              'Alejandro Zendejas' : 0,
              'Luca de la Torre' : 0,
              'Paxten Aaronson' : 0,
              'Alex Mendez': 0,
              'Taylor Booth': 0,
              'Keaton Parks': 0,
              'Richie Ledezma': 0,
              'Malik Tillman': 0,
              'Tyler Adams': 0,
              'Djordje Mihailovic': 0,
              'Tim Tillman': 0,
              'Unknown': 0}

lcm_starts1 = july_resps[15].value_counts()
lcm_starts2 = july_resps[37].value_counts()
lcm_starts = lcm_starts1.add(lcm_starts2, fill_value=0)

rcm_starts1 = july_resps[16].value_counts()
rcm_starts2 = july_resps[38].value_counts()
rcm_starts = rcm_starts1.add(rcm_starts2, fill_value=0)

lcm_count = cm_starter_counts(lcm_starts, lcm_counts, player_mistakes)

rcm_count = cm_starter_counts(rcm_starts, rcm_counts, player_mistakes)

# %%
lcm_count
# Out:
# Weston McKennie    13.0
# Yunus Musah        18.0
# Gio Reyna           3.0
# Tyler Adams        12.0
# dtype: float64

# %%
sum(lcm_count)
# Out:
# 46.0

# %%
rcm_count
# Out:
# Weston McKennie    14.0
# Yunus Musah        15.0
# Gio Reyna           8.0
# Tyler Adams         9.0
# dtype: float64

# %%
sum(rcm_count)
# Out:
# 46.0

# %%
lw_counts = {'Christian Pulisic' : 0,
             'Tim Weah': 0,
             'Gio Reyna': 0,
             'Brendan Aaronson': 0,
             'Alejandro Zendejas': 0,
             'Taylor Booth': 0,
             'Kevin Paredes': 0,
             'Malik Tillman': 0,
             'Matthew Hoppe': 0,
             'Quinn Sullivan': 0,
             'Paul Arriola': 0,
             'Caden Clark': 0,
             'Sergino Dest': 0,
             'Josh Sargent': 0,
             'Unknown': 0}

rw_counts = {'Christian Pulisic' : 0,
             'Tim Weah': 0,
             'Gio Reyna': 0,
             'Brendan Aaronson': 0,
             'Alejandro Zendejas': 0,
             'Taylor Booth': 0,
             'Kevin Paredes': 0,
             'Malik Tillman': 0,
             'Matthew Hoppe': 0,
             'Quinn Sullivan': 0,
             'Paul Arriola': 0,
             'Caden Clark': 0,
             'Sergino Dest': 0,
             'Josh Sargent': 0,
             'Unknown': 0}

lw_starts1 = july_resps[18].value_counts()
lw_starts2 = july_resps[40].value_counts()
lw_starts = lw_starts1.add(lw_starts2, fill_value=0)

rw_starts1 = july_resps[19].value_counts()
rw_starts2 = july_resps[41].value_counts()
rw_starts = rw_starts1.add(rw_starts2, fill_value=0)

lw_count = wing_starter_counts(lw_starts, lw_counts, player_mistakes)

rw_count = wing_starter_counts(rw_starts, rw_counts, player_mistakes)

# %%
lw_count
# Out:
# Christian Pulisic    45.0
# Tim Weah              1.0
# dtype: float64

# %%
sum(lw_count)
# Out:
# 46.0

# %%
rw_count
# Out:
# Christian Pulisic     1.0
# Tim Weah             43.0
# Gio Reyna             1.0
# Taylor Booth          1.0
# dtype: float64

# %%
sum(rw_count)
# Out:
# 46.0

# %%
st_counts = {'Ricardo Pepi' : 0,
             'Gio Reyna': 0,
             'Jesus Ferreira': 0,
             'Jordan Pefok': 0,
             'Daryl Dike': 0,
             'Josh Sargent': 0,
             'Brandon Vazquez': 0,
             'Folarin Balogun': 0,
             'Cade Cowell': 0,
             'Gyasi Zardes': 0,
             'Malik Tillman': 0,
             'Matthew Hoppe': 0,
             'Tim Weah': 0,
             'Unknown': 0}

st_starts1 = july_resps[21].value_counts()
st_starts2 = july_resps[43].value_counts()
st_starts = st_starts1.add(st_starts2, fill_value=0)

st_count = st_starter_counts(st_starts, st_counts, player_mistakes)

# %%
st_count
# Out:
# Folarin Balogun    46.0
# dtype: float64

# %%
sum(st_count)
# Out:
# 46.0

# %%
plot_starter_pies('July 2023', gk_count, rb_count, lb_count, lcb_count,
                     rcb_count, cdm_count, lcm_count, rcm_count, cam_count, 
                     lw_count, rw_count, st_count)

# %% [markdown]
# # Last 3 In

# %%
last_3_in = dict()

for key in player_mistakes.keys():
    last_3_in[key] = 0

# %%
last_man_1_1 = july_resps[22].value_counts()
last_man_1_2 = july_resps[23].value_counts()
last_man_1_3 = july_resps[24].value_counts()

last_man_2_1 = july_resps[44].value_counts()
last_man_2_2 = july_resps[45].value_counts()
last_man_2_3 = july_resps[46].value_counts()

last_men1 = last_man_1_1.add(last_man_1_2, fill_value=0).add(last_man_1_3, fill_value=0)
last_men2 = last_man_2_1.add(last_man_2_2, fill_value=0).add(last_man_2_3, fill_value=0)

last_men = last_men1.add(last_men2, fill_value=0)

# %%
for man in last_men.index:
    print(man)
# Out:
# Aaronson
# Adams
# Alejandro Zendejas
# Austin Trusty
# Auston Trusty
# Brandon Vasquez
# Brendan Aaronson
# Brendan Aaronson
# Brendon Aaronson
# Brooks
# Bryan Reynolds
# Busio
# CCV
# Cade Cowell
# Cade Cowell
# Cardoso
# Che Justin
# Cowell
# DeJuan Jones
# Diego Luna
# Djordje Mihailovic
# Erik Palmer-Brown
# Ferraira
# Ferreira
# Ferreira
# Ferriera
# Haji Wright
# Jack McGlynn
# Jalen Neal
# James Sands
# Jesus Ferreira
# Jesus Ferreira
# Jesús ferreira
# Johnathan Gomez
# Johnny
# Johnny Cardoso
# Johnny Cordoso
# Josh Sargent
# Josh Sargent
# Josh Wynder
# Joshua Sargent
# Kevin Paredes
# Luca de la torre
# Luchio Acosta
# Luna
# Malik Tillman
# Malik Tillman
# Mark McKenzie
# Matt Miagza
# McGlynn
# Mihailovic
# Miles Robinson
# Neal
# Noel Buck
# Obed Vargas
# Parades
# Paredes
# Paxten Aaronson
# Paxten Aaronson
# Pepi
# Reggie Cannon
# Sands
# Sargent
# Sargent
# Scally
# Taylor Booth
# Taylor Booth
# Tillman
# Tim Ream
# Tim ream
# Tolkin
# Trusty
# Walker Zimmerman
# ...

# %%
last_3_filler(player_mistakes, last_men, last_3_in)

# %%
sum(last_3_in.values())
# Out:
# 133.0

# %%
sum(last_3_in.values()) / 3
# Out:
# 44.333333333333336

# %%
last_3_in = pd.Series(last_3_in)
last_3_in = last_3_in[last_3_in!=0]

for ind, val in zip(last_3_in.sort_values(ascending=False).index, last_3_in.sort_values(ascending=False)):
    print(ind, val)
# Out:
# Josh Sargent 25.0
# Jesus Ferreira 12.0
# Taylor Booth 8.0
# Johnny Cardoso 7.0
# Diego Luna 7.0
# Paxten Aaronson 6.0
# Malik Tillman 6.0
# Kevin Paredes 5.0
# Djordje Mihailovic 5.0
# Brendan Aaronson 5.0
# Cade Cowell 4.0
# James Sands 4.0
# Miles Robinson 3.0
# Auston Trusty 3.0
# Tim Ream 3.0
# Jalen Neal 2.0
# Alejandro Zendejas 2.0
# Jack McGlynn 2.0
# Walker Zimmerman 2.0
# Haji Wright 2.0
# Bryan Reynolds 2.0
# Gianluca Busio 1.0
# Joshua Wynder 1.0
# Jonathan Gomez 1.0
# Joe Scally 1.0
# Luca de la Torre 1.0
# Brandon Vazquez 1.0
# Ricardo Pepi 1.0
# Reggie Cannon 1.0
# Obed Vargas 1.0
# Tyler Adams 1.0
# Justin Che 1.0
# Erik Palmer-Brown 1.0
# Mark McKenzie 1.0
# Cameron Carter-Vickers 1.0
# John Brooks 1.0
# Caleb Wiley 1.0
# John Tolkin 1.0
# Noel Buck 1.0
